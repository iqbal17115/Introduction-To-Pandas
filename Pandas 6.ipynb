# %%
import pandas as pd

# %%
df=pd.read_csv('car-speed.csv')

# %%
df.head()
# Out:
#    speed  car_age  experience  age
# 0    200       15         5.0   85
# 1     90       17        13.0   20
# 2    165       12         4.0   93
# 3    110       20         NaN   60
# 4    140        5         3.0   82

# %%
df.head(1)
# Out:
#    speed  car_age  experience  age
# 0    200       15         5.0   85

# %%
df.head(2)
# Out:
#    speed  car_age  experience  age
# 0    200       15         5.0   85
# 1     90       17        13.0   20

# %%
df.tail()
# Out:
#    speed  car_age  experience  age
# 1     90       17        13.0   20
# 2    165       12         4.0   93
# 3    110       20         NaN   60
# 4    140        5         3.0   82
# 5    115        2         8.0   10

# %%
df.tail(1)
# Out:
#    speed  car_age  experience  age
# 5    115        2         8.0   10

# %%
df.tail(2)
# Out:
#    speed  car_age  experience  age
# 4    140        5         3.0   82
# 5    115        2         8.0   10

# %%
pd.read_csv('car-speed.csv', dtype={'age':'float64'})
# Out:
#    speed  car_age  experience   age
# 0    200       15         5.0  85.0
# 1     90       17        13.0  20.0
# 2    165       12         4.0  93.0
# 3    110       20         NaN  60.0
# 4    140        5         3.0  82.0
# 5    115        2         8.0  10.0

# %%
pd.read_csv('car-speed.csv', dtype={'age':'float64', 'age': 'float64'})
# Out:
#    speed  car_age  experience   age
# 0    200       15         5.0  85.0
# 1     90       17        13.0  20.0
# 2    165       12         4.0  93.0
# 3    110       20         NaN  60.0
# 4    140        5         3.0  82.0
# 5    115        2         8.0  10.0

# %%
pd.read_csv('car-speed.csv', true_values=['Yes'])
# Out:
#    speed  car_age  experience  age
# 0    200       15         5.0   85
# 1     90       17        13.0   20
# 2    165       12         4.0   93
# 3    110       20         NaN   60
# 4    140        5         3.0   82
# 5    115        2         8.0   10

# %%
pd.read_csv('car-speed.csv', false_values=['No'])

# %%
pd.read_csv('car-speed.csv', true_values=['Yes'], false_values=['No'])
# Out:
#    speed  car_age  experience  age
# 0    200       15         5.0   85
# 1     90       17        13.0   20
# 2    165       12         4.0   93
# 3    110       20         NaN   60
# 4    140        5         3.0   82
# 5    115        2         8.0   10
