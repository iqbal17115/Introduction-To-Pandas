# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'Id': [1, 2, 3, 4], 'Class': [9, 10, 11, 12]})
df1
# Out:
#    Id  Class
# 0   1      9
# 1   2     10
# 2   3     11
# 3   4     12

# %%
df2 = pd.DataFrame({'Id': [1, 2, 3, 5], 'Name': ['A', 'B', 'C', 'D']})
df2
# Out:
#    Id Name
# 0   1    A
# 1   2    B
# 2   3    C
# 3   5    D

# %%
pd.merge(df1, df2, on='Id')
# Out:
#    Id  Class Name
# 0   1      9    A
# 1   2     10    B
# 2   3     11    C

# %%
pd.merge(df1, df2, on='Id', how='inner')
# Out:
#    Id  Class Name
# 0   1      9    A
# 1   2     10    B
# 2   3     11    C

# %%
pd.merge(df1, df2, on='Id', how='left')
# Out:
#    Id  Class Name
# 0   1      9    A
# 1   2     10    B
# 2   3     11    C
# 3   4     12  NaN

# %%
pd.merge(df2, df1, on='Id', how='right')
# Out:
#    Id Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4  NaN     12

# %%
pd.merge(df2, df1, on='Id', how='outer')
# Out:
#    Id Name  Class
# 0   1    A    9.0
# 1   2    B   10.0
# 2   3    C   11.0
# 3   5    D    NaN
# 4   4  NaN   12.0

# %%
pd.merge(df1, df2, on='Id', how='outer', indicator=True)
# Out:
#    Id  Class Name      _merge
# 0   1    9.0    A        both
# 1   2   10.0    B        both
# 2   3   11.0    C        both
# 3   4   12.0  NaN   left_only
# 4   5    NaN    D  right_only

# %%
df1
# Out:
#    Id  Class
# 0   1      9
# 1   2     10
# 2   3     11
# 3   4     12

# %%
df2
# Out:
#    Id Name
# 0   1    A
# 1   2    B
# 2   3    C
# 3   5    D

# %%
df2 = pd.DataFrame({'Id': [1, 2, 3, 5], 'Name': ['A', 'B', 'C', 'D']})
df2
# Out:
#    Id Name
# 0   1    A
# 1   2    B
# 2   3    C
# 3   5    D

# %%
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
#    Id_x  Class  Id_y Name
# 0     1      9     1    A
# 1     2     10     2    B
# 2     3     11     3    C
# 3     4     12     5    D

# %%
df1 = pd.DataFrame({'Id': [1, 2, 3, 5], 'Name': [9, 10, 11, 12]})
df1
# Out:
#    Id  Name
# 0   1     9
# 1   2    10
# 2   3    11
# 3   5    12

# %%
df2 = pd.DataFrame({'Id': [1, 2, 3, 5], 'Name': [9, 10, 11, 12]})
df2
# Out:
#    Id  Name
# 0   1     9
# 1   2    10
# 2   3    11
# 3   5    12

# %%
pd.merge(df1, df2, on='Id', suffixes=('_Higher', '_Middle'))
# Out:
#    Id  Name_Higher  Name_Middle
# 0   1            9            9
# 1   2           10           10
# 2   3           11           11
# 3   5           12           12
